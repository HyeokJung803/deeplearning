# %% [markdown]
# # 텐서플로우 / Keras

# %%
import numpy as np
import tensorflow as tf
import keras

# %%
tf.__version__
# Out:
# '2.21.0'

# %%
keras.__version__
# Out:
# '3.14.1'

# %%
keras.config.backend()
# Out:
# 'tensorflow'

# %%
# 0차원 - 스칼라 - 숫자 하나
scalar = tf.constant(3.14)

# %%
# 1차원 - 벡터 - 피처 1개의 샘플 or 샘플 1개의 피처값들
vector = tf.constant([1,2,3])

# %%
# 2차원 - 행렬 - 표, 테이블
matrix = tf.constant([
    [1, 2, 3],
    [4, 5, 6]
])  # (2, 3의 행렬)

matrix = tf.zeros((100, 3)) # (100, 3)의 0 행렬
matrix.shape
# Out:
# TensorShape([100, 3])

# %%
# 3차원 - (샘플 수 * 높이 * 너비) - 이미지
tensor_3d = tf.zeros((300, 100, 100))
tensor_3d.shape
# Out:
# TensorShape([300, 100, 100])

# %%
# 차원 확인하기
tensor_3d.ndim
# Out:
# 3

# %%
# tensor -> numpy
type(tensor_3d.numpy())
# Out:
# numpy.ndarray

# %% [markdown]
# # Keras : 고수준 API
# - Sequntial : 층을 순서대로 쌓겠다.
# - Dense : 퍼셉트론 여러개를 하나의 층으로 묶은 연결층
# - ...
#
# 1. 모델을 정으힌다
# 2. 레이어 블록을 쌓는다.
# 3. 컴파일 한다.
# 4. 학습한다.
# 5. 평가한다.

# %%
a = tf.constant([1,2], [3,4])
b = tf.constant([0.1,0.2], [0.3,0,4])

c = tf.matmul(a , b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\student\p1-data\c3-deep-leanring\.venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:104, in convert_to_eager_tensor(value, ctx, dtype)
#     103 try:
# --> 104   dtype = dtype.as_datatype_enum
#     105 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'as_datatype_enum'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a = tf.constant([1,2], [3,4])
#       2 b = tf.constant([0.1,0.2], [0.3,0,4])
#       3
#       4 c = tf.matmul(a , b)
#
# File c:\Users\student\p1-data\c3-deep-leanring\.venv\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\student\p1-data\c3-deep-leanring\.venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)    274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File c:\Users\student\p1-data\c3-deep-leanring\.venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:288, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     286   if trace.enabled:
#     287     with trace.Trace("tf.constant"):
# --> 288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#
# File c:\Users\student\p1-data\c3-deep-leanring\.venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:301, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     297 def _constant_eager_impl(
#     298     ctx, value, dtype, shape, verify_shape
#     299 ) -> ops._EagerTensorBase:
#     300   """Creates a constant on the current device."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# File c:\Users\student\p1-data\c3-deep-leanring\.venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:106, in convert_to_eager_tensor(value, ctx, dtype)
#     104     dtype = dtype.as_datatype_enum
#     105   except AttributeError:
# --> 106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
#     108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# File c:\Users\student\p1-data\c3-deep-leanring\.venv\Lib\site-packages\tensorflow\python\framework\dtypes.py:944, in as_dtype(type_value)
#     941 if isinstance(type_value, _dtypes.DType):
#     942   return _INTERN_TABLE[type_value.as_datatype_enum]
# --> 944 raise TypeError(f"Cannot convert the argument `type_value`: {type_value!r} "
#     945                 "to a TensorFlow DType.")
#
# TypeError: Cannot convert the argument `type_value`: [3, 4] to a TensorFlow DType.

# %%
# AI에게 텐서 연산 만들어줘
